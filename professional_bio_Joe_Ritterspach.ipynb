# %% [markdown]
# # Joe Ritterspach
#
# ![headshot](headshot_2025.jpg)
#
# I'm currently a third year student at The University of Cincinnati. I enjoy reading and doing calisthenics in my free time, and I want to start my own investment firm someday.
# ## Academic Background
# - The University of Cincinnati; expected graduation of May, 2027; GPA of 3.75
#     - BS, Business Analytics
#     - BBA, Finance
# ## Professional Experience
# - QA Operational Finance Intern, *Kroger*
#     - Skills used/learned: Excel for data analysis, financial statement analysis, Oracle, and PowerPoint
# ## Skills and Goals
# Sharpe ratio: $𝛂/𝛔$
# 1. Get a summer 2026 internship
# 2. Get a role in some investment industry after graduation
# 3. Create my own investment firm by age 30
# [LinkedIn](https://www.linkedin.com/in/joe-ritterspach/)
# ## Code Demonstration
# *Countdown to deadline for creating my own firm (age 30)*

# %%
import datetime as dt
from datetime import datetime, date

birthday = date(2005, 8, 19)
thirtieth_birthday = date(birthday.year + 30, birthday.month, birthday.day)
today = dt.date.today()

days_til_thirty = (thirtieth_birthday - today).days

print(f"Days until I turn 30: {days_til_thirty}")
